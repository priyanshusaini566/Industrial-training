# %% [markdown]
# # question-1

# %%
# Write a program to check whether a number entered by the user is even or odd.
a = int(input("enter the number : "))
if a % 2 == 0:
    print("the number is an even number")
else:
    print("the number is odd")
# Out:
# the number is an even number

# %% [markdown]
# # question-2

# %%
"""
Write a program that takes a user's age and prints:

"Child" if age < 13
"Teen" if age is between 13 and 19
"Adult" if age is 20 and above
"""
age=int(input("Enter the age of user : "))
if age<13:
    print("Child")
elif age>13 and age<19:
    print("Teen")
else:
    print("Adult")
# Out:
# Adult

# %% [markdown]
# # question-3

# %%
# Write a program to find the largest of two numbers.
x=int(input("Enter the 1st number : "))
y=int(input("Ente the 2nd number : "))
if(x>y):
    print("1st is greater than 2nd")
else:
    print("2nd is greater than 1st")
# Out:
# 2nd is greater than 1st

# %% [markdown]
# # qustion-4

# %%
# Write a program to find the largest of three numbers.
p=int(input("enter the value of p : "))
q=int(input("enter the value of q : "))
r=int(input("enter the value of r : "))
if p>q:
    if p>r:
        print("p is greatest")
    else:
     print("r is largest")
elif q>r:
   print("q is largest")
else:
   print("r is largest")
# Out:
# q is largest

# %% [markdown]
# # question-5

# %%
# Write a program to check whether a given year is a leap year or not
year=int(input("Enter the year : "))
if year%100==0 and year%400==0:
    print(year," is a leap year")
elif year%4==0 and year%10!=0:
    print(year," is a leap year")
else:
    print(year," is not a leap year")
# Out:
# 2026  is not a leap year

# %% [markdown]
# # question-6

# %%
"""
Write a program that prints:

"Divisible by both 3 and 5"
"Divisible by 3 only"
"Divisible by 5 only"
"Not divisible by 3 or 5" based on user input.
"""
num=int(input("Enter the number : "))
if num%3==0 and num%5==0:
    print("Divisible by both 3 and 5")
elif num%3==0:
    print("Divisible by 3 only")
elif num%5==0:
    print("Divisible by 5 only")
else:
    print("Not Divisible by 3 or 5")
# Out:
# Divisible by both 3 and 5

# %% [markdown]
# # question-7

# %%
# Write a program that checks if a given alphabet is a vowel or consonant.
ch=input("Enter the character : ")
if ch.lower() in "aeiou" :
    print(ch,"is a vowel")
else:
    print(ch,"is a consonant")
# Out:
# P is a consonant

# %% [markdown]
# # question-8

# %%
"""
Write a program that takes temperature in Celsius and prints:

"Cold" if below 10
"Pleasant" if between 10 and 25
"Hot" if above 25
"""
temp=float(input("Enter the temperatur in *C : "))
if temp<=10:
    print("Cold")
elif temp>10 and temp<=25:
    print("Pleasant")
else:
    print("Hot")
# Out:
# Hot

# %% [markdown]
# # question-9

# %%
"""
Write a program that prints a grade based on marks:

A: 90–100
B: 75–89
C: 50–74
F: Below 50
"""
marks=int(input("Enter the marks : "))
if marks<50:
    print("grade is F")
elif marks>=50 and marks<75:
    print("grade is C")
elif marks>=75 and marks<=89:
    print("grade is B")
else:
    print("grade is A")
# Out:
# grade is A

# %% [markdown]
# # question-10

# %%
# Write a program to simulate ATM withdrawal : allow only if amount is a multiple of 100 and less than or equal to balance.
balance = 10000
amount = int(input("Enter the amount to withdraw : "))
if amount%10==0 and amount<=balance:
    print("Allowed")
else:
    print("not allowed")
# Out:
# Allowed

# %% [markdown]
# # question-11

# %%
# Write a program that acts as a simple calculator using two numbers and an operator (+, –, *, /).
a=int(input("Enter the 1st number : "))
b=int(input("Enter the 2nd number : "))
ch=input("Enter the character among (+,-,*,/)")

match ch:
    case '+':
        print("the addition will be :",a+b)
    case '-':
        print("the subtraction will be : ",a-b)
    case '*':
        print("the multiplication will be :",a*b)
    case '/':
        print("the division will be : ",a/b) 
    case _:
        print("invalid operator")
# Out:
# the multiplication will be : 6
