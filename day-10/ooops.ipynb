# %% [markdown]
# # encapsulation

# %%
class Bank:
    def __init__(self, acc_no,name,balance):
        self.__acc_no=acc_no
        self.__name=name
        self.__balance=balance

    def getdetails(self):
        return self.__name,self.__balance,self.__acc_no

# %%
b=Bank(4100,"ps",10000)

# %%
b.getdetails()
# Out:
# ('ps', 10000, 4100)

# %%
# abstraction
from abc import ABC, abstractmethod

class Car(ABC):
    @abstractmethod
    def mileage(self):
        pass
    @abstractmethod
    def top_speed(self):
        pass
    @abstractmethod
    def safety(self):
        pass

class Ferrari(Car):
    def price(self):
        return "3.2cr"
    def mileage(self):
        return 3
    def top_speed(self):
        return "320 kmph"
    def safety(self):
        return "5 star"

# %%
f = Ferrari()

# %%
f.price()
# Out:
# '3.2cr'

# %% [markdown]
# # polymorphism

# %%
class methodoverloading:
    def add(self,x,y):
        return x+y
    def add(self,x,y,z):
        return x+y+z

# %%
mo=methodoverloading()

# %%
mo.add(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 mo.add(1,2)
#
# TypeError: methodoverloading.add() missing 1 required positional argument: 'z'
